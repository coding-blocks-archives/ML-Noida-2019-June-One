# %%
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

import random

import cv2

# %%
img = cv2.imread("strange.jpg")

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (464, 825, 3)

# %%
X = img.reshape(-1, 3)

# %%
second = X.reshape(img.shape)

# %%
X.shape
# Out:
# (382800, 3)

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(10)

# %%
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=10, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
color_pellet = model.cluster_centers_

# %%
color_pellet
# Out:
# array([[ 73.19195497,  89.69620069, 105.32267456],
#        [250.81738785, 252.72958846, 250.60290128],
#        [ 14.59050403,  14.46089546,  27.2678469 ],
#        [246.2583858 , 204.87735165, 150.87441328],
#        [211.62555108,  94.15452441,  50.10032034],
#        [181.9757398 , 200.25984182, 201.36172576],
#        [229.90133838, 148.73344674,  95.33084058],
#        [135.00038821,  46.44230209,  35.41816829],
#        [ 42.10687408,  39.21539373,  50.63356518],
#        [119.64047453, 145.74040475, 153.60846709]])

# %%
for color in color_pellet:
    color_img = np.zeros([100, 100, 3])
    color_img[:, :] = color
    plt.figure()
    plt.imshow(color_img.astype(int))

# %%
# plt.imshow(color_pellet.reshape(2, 2, 3) / 255)

# %%
gen = np.zeros([X.shape[0], 3])

# %%
for i in range(len(gen)):
    gen[i] = color_pellet[model.labels_[i]]
    
gen = gen.reshape(img.shape)

# %%
plt.imshow(gen/255)

# %%
gen = cv2.rectangle(gen, (0, 0), (100, 100), (255, 255, 255), 4)

# %%
plt.imshow(gen/255)
