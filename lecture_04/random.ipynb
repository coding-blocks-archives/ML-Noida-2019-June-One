# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.randn(100)

# %%
# data.astype(int)

# %%
np.random.normal(5, 2, 10)
# Out:
# array([2.86581751, 5.99147067, 5.46221712, 6.31937995, 4.02413594,
#        4.83192449, 3.56768823, 2.63688612, 2.97403413, 5.94560806])

# %%
np.random.multivariate_normal?

# %%
mean1 = [4, 5]

# %%
cov = [[1, -.5], [-.5, 1]]

# %%
dist1 = np.random.multivariate_normal(mean1, cov, 1000)

# %%
dist1.shape
# Out:
# (1000, 2)

# %%
plt.figure()
plt.scatter(dist1[:, 0], dist1[:, 1], s=10)
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.show()

# %%
m1 = [4, 6]
m2 = [8, 10]
cov = [[1, 0], [0, 1]]

dis1 = np.random.multivariate_normal(m1, cov, 500)
dis2 = np.random.multivariate_normal(m2, cov, 500)

# %%
plt.figure()
plt.scatter(dis1[:, 0], dis1[:, 1], s=10)
plt.scatter(dis2[:, 0], dis2[:, 1], s=10)
plt.xlim(0, 15)
plt.ylim(0, 15)
plt.show()

# %%
up1 = np.hstack([np.ones([dis1.shape[0],1]), dis1])
up2 = np.hstack([np.zeros([dis2.shape[0],1]), dis2])

# %%
up2.shape
# Out:
# (500, 3)

# %%
data = np.vstack([up1, up2])

# %%
data.shape
# Out:
# (1000, 3)

# %%
point = np.array([7, 7])

# %%
plt.scatter(data[:, 1], data[:, 2], c=data[:, 0])
plt.scatter(point[0], point[1], s = 100)

# %%
np.mean(dis2, axis=0)
# Out:
# array([ 7.99847217, 10.03741303])

# %%
def distance(a, b):
    return np.sum((a - b) ** 2)

# %%
p1 = np.array([1, 1])
p2 = np.array([4, 5])

print(distance(p1, p2))
# Out:
# 25

# %%
def knn(X, y, point, k):
    
    distances = []
    
    for tup in zip(X, y):
        dis = distance(point, tup[0])
        distances.append((dis, tup[1]))
    
    distances = sorted(distances)
    top = np.array(distances[:k])
    
    vals, occ = np.unique(top[:, 1], return_counts=True)
    # argmax is for index of max item
    return vals[np.argmax(occ)]

# %%
point = np.array([7, 7])
X = data[:, 1:]
y = data[:, 0]

# %%
knn(X, y, point, 10)
# Out:
# (array([0., 1.]), array([4, 6]))

# %%
list(zip([0, 1, 2], [("ram", 11), ("mohan", 22), "seeta"]))
# Out:
# [(0, ('ram', 11)), (1, ('mohan', 22)), (2, 'seeta')]
